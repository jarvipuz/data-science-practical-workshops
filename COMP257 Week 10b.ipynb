# %% [markdown]
# # Naive Bayes

# %% [markdown]
# Naive Bayes methods are a set of supervised learning algorithms based on applying Bayes' theorem with the "naive" assumption of conditional independence between every pair of features given the value of the class variable. Bayes'theorem states the following relationship, given class variable $y$ and dependent feature vector $x_1$ through $x_n$,:

# %% [markdown]
# $$P(y \mid x_1, \dots, x_n) = \frac{P(y) P(x_1, \dots x_n \mid y)}
#                                  {P(x_1, \dots, x_n)}$$

# %% [markdown]
# Using the naive conditional independence assumption, we have

# %% [markdown]
# $$\begin{align}\begin{aligned}P(y \mid x_1, \dots, x_n) \propto P(y) \prod_{i=1}^{n} P(x_i \mid y)\\\Downarrow\\\hat{y} = \arg\max_y P(y) \prod_{i=1}^{n} P(x_i \mid y),\end{aligned}\end{align}$$

# %% [markdown]
# Then, we can use Maximum A Posteriori (MAP) estimation to estimate $P(y)$ and $P(x_i \mid y)$; the former is then the relative frequency of class $y$ in the training set.

# %% [markdown]
# *References*:
# H. Zhang (2004). The optimality of Naive Bayes. Proc. FLAIRS.

# %% [markdown]
# # 1 Gaussian Naive Bayes

# %% [markdown]
# GaussianNB implements the Gaussian Naive Bayes algorithm for classification.
# The likelihood of the features is assumed to be Gaussian:

# %% [markdown]
# $$P(x_i \mid y) = \frac{1}{\sqrt{2\pi\sigma^2_y}} \exp\left(-\frac{(x_i - \mu_y)^2}{2\sigma^2_y}\right)$$

# %% [markdown]
# The parameters $\sigma_y$ and $\mu_y$  are estimated using maximum likelihood.

# %% [markdown]
# **Example** - The training data is generated as follows:

# %%
import numpy as np
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
Y = np.array([1, 1, 1, 2, 2, 2])

# %% [markdown]
# **Q1**: Training a GaussianNB model:

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X, Y)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# **Q2**: Predict the label of a data [-0.8,-1]:

# %%
X_test = np.array([[-0.8, -1], [-10, -10], [1, 1]])
y_pred = gnb.predict(X_test)
y_pred
# Out:
# array([1, 1, 2])

# %% [markdown]
# # 2 MultinomialNB

# %% [markdown]
# The multinomial Naive Bayes classifier is suitable for classification with discrete features (e.g., word counts for text classification).

# %% [markdown]
# *References*
# C.D. Manning, P. Raghavan and H. Schuetze (2008). Introduction to Information Retrieval. Cambridge University Press, pp. 234-265. http://nlp.stanford.edu/IR-book/html/htmledition/naive-bayes-text-classification-1.html

# %% [markdown]
# **Example** - The training data is generated as follows:

# %%
import numpy as np
X = np.random.randint(5, size=(6, 100))
y = np.array([1, 2, 3, 4, 5, 6])
X.shape
# Out:
# (6, 100)

# %% [markdown]
# **Q3**: Training a MultinomialNB model:

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(X, y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# **Q4**: Predict the label of a data X[2:3]:

# %%
mnb.predict(X[1:4])
# Out:
# array([2, 3, 4])

# %%
X[1:4]
# Out:
# array([[3, 4, 1, 0, 4, 1, 4, 1, 3, 1, 2, 1, 2, 3, 4, 4, 1, 0, 2, 4, 3, 4,
#         4, 2, 2, 1, 0, 2, 1, 0, 0, 1, 1, 4, 0, 2, 0, 0, 0, 3, 3, 1, 3, 0,
#         0, 2, 2, 4, 2, 3, 4, 0, 0, 3, 1, 4, 1, 0, 2, 1, 4, 2, 3, 1, 1, 2,
#         0, 1, 1, 4, 0, 4, 1, 0, 3, 2, 2, 2, 3, 2, 3, 0, 1, 3, 1, 2, 1, 2,
#         1, 2, 1, 3, 2, 0, 0, 1, 1, 0, 3, 1],
#        [1, 1, 0, 3, 4, 1, 2, 1, 1, 0, 1, 1, 4, 4, 3, 3, 0, 0, 4, 3, 3, 3,
#         2, 2, 1, 1, 4, 3, 3, 1, 2, 4, 0, 1, 4, 0, 4, 2, 2, 0, 4, 2, 1, 1,
#         3, 4, 3, 4, 3, 4, 4, 3, 3, 4, 1, 4, 1, 3, 1, 2, 4, 1, 4, 3, 1, 2,
#         2, 4, 2, 4, 4, 0, 3, 2, 3, 4, 1, 0, 2, 3, 4, 2, 2, 4, 3, 4, 0, 0,
#         2, 1, 2, 1, 4, 1, 0, 0, 2, 1, 0, 0],
#        [1, 1, 0, 0, 2, 1, 0, 3, 1, 4, 4, 3, 0, 4, 2, 3, 2, 2, 1, 0, 0, 4,
#         3, 0, 4, 1, 3, 2, 2, 4, 1, 2, 1, 3, 0, 4, 3, 4, 2, 4, 4, 0, 1, 1,
#         3, 1, 0, 2, 4, 2, 3, 4, 0, 3, 1, 3, 4, 2, 3, 0, 0, 2, 2, 1, 3, 0,
#         1, 3, 3, 1, 0, 3, 2, 2, 1, 3, 1, 4, 3, 0, 3, 2, 3, 4, 4, 0, 3, 2,
#         1, 4, 1, 0, 4, 2, 1, 1, 1, 1, 3, 1]])

# %% [markdown]
# # 3 Process on 'Iris' Data

# %% [markdown]
# In Week 9, we have studied how to use KNN algorithm to do classification task on 'iris' data. Here,we are going to employ the GaussianNB to conduct the same task.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris_dataset = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
iris_dataset['data'], iris_dataset['target'], random_state=0)

# %%
print('Dimensions of X_train: ', X_train.shape)
print('Dimensions of y_train: ', y_train.shape)
print('Dimensions of X_test: ', X_test.shape)
print('Dimensions of y_test: ', y_test.shape)
# Out:
# Dimensions of X_train:  (112, 4)
# Dimensions of y_train:  (112,)
# Dimensions of X_test:  (38, 4)
# Dimensions of y_test:  (38,)

# %% [markdown]
# **Q5**：Report the acuracy result on test data:

# %%
clf1 = GaussianNB()
clf1.fit(X_train, y_train)
clf1_y_pred = clf1.predict(X_test)
print('Accuracy using Gaussian Naive Bayes: ', np.mean(clf1_y_pred == y_test))
# Out:
# Accuracy using Gaussian Naive Bayes:  1.0

# %%
clf2 = MultinomialNB()
clf2.fit(X_train, y_train)
clf2_y_pred = clf2.predict(X_test)
print('Accuracy using Multinomial Naive Bayes: ', np.mean(clf2_y_pred == y_test))
# Out:
# Accuracy using Multinomial Naive Bayes:  0.5789473684210527

# %% [markdown]
# # 4 Predict Human Activity Recognition (HAR)

# %% [markdown]
# The objective of this practice exercise is to predict current human activity based on phisiological activity measurements from 53 different features based in the [HAR dataset](http://groupware.les.inf.puc-rio.br/har#sbia_paper_section). The training (`har_train.csv`) and test (`har_validate.csv`) datasets are provided.

# %% [markdown]
# **Q6**: Build a Naive Bayes model, predict on the test dataset and compute the [confusion matrix](https://towardsdatascience.com/understanding-confusion-matrix-a9ad42dcfd62). Note: Please refer to the [`sklearn.metrics.confusion_matrix`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)

# %%
import pandas as pd
har_train = pd.read_csv('data/har_train.csv')
har_validate = pd.read_csv('data/har_validate.csv')
print('Dimensions of har_train: ', har_train.shape)
print('Dimensions of har_validate: ', har_validate.shape)
# Out:
# Dimensions of har_train:  (13737, 53)
# Dimensions of har_validate:  (5885, 53)

# %%
har_train
# Out:
#       classe  roll_belt  pitch_belt  yaw_belt  total_accel_belt  gyros_belt_x  \
# 0          A       1.41        8.07     -94.4                 3          0.00
# 1          A       1.41        8.07     -94.4                 3          0.02
# 2          A       1.42        8.07     -94.4                 3          0.00
# 3          A       1.48        8.05     -94.4                 3          0.02
# 4          A       1.45        8.06     -94.4                 3          0.02
# 5          A       1.42        8.09     -94.4                 3          0.02
# 6          A       1.42        8.13     -94.4                 3          0.02
# 7          A       1.43        8.16     -94.4                 3          0.02
# 8          A       1.45        8.18     -94.4                 3          0.03
# 9          A       1.43        8.18     -94.4                 3          0.02
# 10         A       1.42        8.20     -94.4                 3          0.02
# 11         A       1.45        8.20     -94.4                 3          0.00
# 12         A       1.57        8.06     -94.4                 3          0.00
# 13         A       1.59        8.07     -94.4                 3          0.02
# 14         A       1.56        8.10     -94.3                 3          0.02
# 15         A       1.51        8.10     -94.4                 3          0.02
# 16         A       1.53        8.11     -94.4                 3          0.03
# 17         A       1.55        8.09     -94.4                 3          0.02
# 18         A       1.54        8.11     -94.4                 3          0.03
# 19         A       1.53        8.14     -94.4                 3          0.03
# 20         A       1.52        8.16     -94.4                 3          0.03
# 21         A       1.52        8.17     -94.4                 3          0.03
# 22         A       1.53        8.17     -94.4                 3          0.02
# 23         A       1.44        8.18     -94.3                 3          0.02
# 24         A       1.41        8.18     -94.4                 3          0.00
# 25         A       1.42        8.12     -94.3                 3          0.00
# 26         A       1.40        8.04     -94.3                 3          0.00
# 27         A       1.40        8.06     -94.3                 3          0.03
# 28         A       1.30        8.00     -94.2                 3         -0.02
# 29         A       1.29        7.81     -94.2                 3         -0.02
# ...      ...        ...         ...       ...               ...           ...
# 13707      E       6.52        5.11     -91.7                 2         -0.10
# 13708      E       7.86        4.34     -91.4                 1         -0.18
# 13709      E       8.11        4.16     -91.4                 1         -0.18
# 13710      E       8.51        3.77     -91.3                 1         -0.16
# 13711      E       8.84        3.50     -91.3                 3         -0.08
# 13712      E       9.05        3.35     -91.2                 2         -0.05
# 13713      E       8.95        3.38     -91.1                 2         -0.03
# 13714      E       8.84        3.41     -91.1                 2          0.00
# 13715      E       8.58        3.50     -91.1                 1          0.06
# 13716      E       8.16        3.80     -91.1                 2          0.10
# 13717      E       8.00        3.97     -91.1                 2          0.10
# 13718      E       7.85        4.18     -91.1                 2          0.08
# 13719      E       7.69        4.34     -91.1                 2          0.06
# 13735                   32             1.48            -0.90             0.05
# 13736                   33             1.38            -0.64             0.08
#
#        accel_forearm_x  accel_forearm_y  accel_forearm_z  magnet_forearm_x  \
# 0                  192              203             -215               -17
# 1                  192              203             -216               -18
# 2                  196              204             -213               -18
# 3                  189              206             -214               -16
# 4                  193              203             -215                -9
# 5                  195              205             -215               -18
# 6                  193              205             -213                -9
# 7                  193              204             -214               -16
# 8                  193              205             -214               -17
# 9                  191              203             -215               -11
# 10                 193              205             -215               -15
# 11                 192              201             -214               -16
# 12                 192              203             -216               -10
# 13                 193              205             -215                -9
# 14                 194              206             -214               -10
# 15                 193              203             -213               -11
# 16                 191              202             -214               -14
# 17                 190              203             -216               -16
# 18                 192              204             -214               -14
# 19                 193              206             -217               -14
# 20                 195              205             -217               -12
# 21                 189              204             -217                -4
# 22                 192              203             -217               -13
# 23                 188              204             -214               -14
# 24                 191              205             -216               -15
# 25                 191              207             -215                -9
# 26                 191              205             -215               -18
# 27                 192              203             -212               -11
# 28                 192              207             -216                -3
# 29                 192              202             -216               -12
# ...                ...              ...              ...               ...
# 13707              -37             -104             -206               -11
# 13708               69             -131             -247               215
# 13709              104             -155             -257               250
# 13710              169             -198             -287               353
# 13711              241             -292             -302               411
# 13712              245             -310             -281               413
# 13713              211             -270             -264               389
# 13714              139             -233             -255               379
# 13715               72             -208             -256               306
# 13716               57             -210             -246               243
# 13717               50             -210             -245               224
# 13718               37             -217             -237               185
# 13719               33             -224             -234               157
# 13720             -237              298               33              -703
# 13721             -107              309               70              -693
# 13722               24              505                7              -463
# 13723               38              496                4              -408
# 13724               64              501                0              -204
# 13725               66              425              -14                 2
# 13726               53              393              -24                67
# 13727               38              391              -35                89
# 13728               40              394              -44                91
# 13729             -193              307                8              -699
# 13730             -203              266               -4              -672
# 13731             -227              236               -1              -622
# 13732             -227              221                0              -592
# 13733             -230              200               -8              -571
# 13734             -263              -99              -45              -116
# 13735             -270             -141              -51               -68
# 13736             -278             -159              -52               -60
#
#        magnet_forearm_y  magnet_forearm_z
# 0                   654               476
# 1                   661               473
# 2                   658               469
# 3                   658               469
# 4                   660               478
# 5                   659               470
# 6                   660               474
# 7                   653               476
# 8                   657               465
# 9                   657               478
# 10                  655               472
# 11                  656               472
# 12                  657               466
# 13                  657               480
# 14                  653               467
# 15                  661               470
# 16                  667               470
# 17                  658               462
# 18                  657               467
# 19                  657               477
# 20                  657               469
# 21                  661               479
# 22                  660               469
# 23                  656               465
# 24                  651               464
# 25                  654               471
# 26                  651               469
# 27                  655               470
# 28                  653               460
# 29                  652               464
# ...                 ...               ...
# 13707              -605                60
# 13708              -630               -53
# 13709              -632               -78
# 13710              -621              -167
# 13711              -618              -251
# 13712              -639              -286
# 13713              -653              -266
# 13714              -654              -259
# 13715              -666              -177
# 13716              -665              -137
# 13717              -672              -132
# 13718              -673              -117
# 13719              -672              -108
# 13720               382               803
# 13721               517               890
# 13722               839               905
# 13723               852               878
# 13724               821               777
# 13725               712               630
# 13726               653               537
# 13727               633               512
# 13728               629               488
# 13729               229               596
# 13730               119               540
# 13731               -11               480
# 13732               -85               431
# 13733              -126               404
# 13734              -654               -70
# 13735              -678               -98
# 13736              -686              -110
#
# [13737 rows x 53 columns]

# %%
X_train = har_train.drop('classe', axis = 1)
y_train = har_train['classe']
X_test = har_validate.drop('classe', axis = 1)
y_test = har_validate['classe']
print('Dimensions of X_train: ', X_train.shape)
print('Dimensions of y_train: ', y_train.shape)
print('Dimensions of X_test: ', X_test.shape)
print('Dimensions of y_test: ', y_test.shape)
# Out:
# Dimensions of X_train:  (13737, 52)
# Dimensions of y_train:  (13737,)
# Dimensions of X_test:  (5885, 52)
# Dimensions of y_test:  (5885,)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print('Accuracy of Gaussian Naive Bayes: ', np.mean(y_test == y_pred))
# Out:
# Accuracy of Gaussian Naive Bayes:  0.5542905692438402

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1070,   95,  262,  212,   35],
#        [ 127,  685,  145,   76,  106],
#        [ 223,  106,  512,  136,   49],
#        [ 102,   35,  271,  441,  115],
#        [  51,  239,   95,  143,  554]])

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [KNeighborsClassifier(3),
               SVC(kernel="linear", C=0.025),
               SVC(gamma=2, C=1),
               GaussianProcessClassifier(1.0 * RBF(1.0)),
               DecisionTreeClassifier(max_depth=5),
               RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
               MLPClassifier(alpha=1, max_iter=1000),
               AdaBoostClassifier(),
               GaussianNB(),
               QuadraticDiscriminantAnalysis()]

# %%
#for name, clf in zip(names, classifiers):
#    print('classifier: ', name)
#    clf.fit(X_train, y_train)
#    score = clf.score(X_test, y_test)
#    print('Accuracy: ', score)

# %%
knn = KNeighborsClassifier(3)
svc_l = SVC(kernel="linear", C=0.025)
svc_g = SVC(gamma=2, C=1)
gpc = GaussianProcessClassifier(1.0 * RBF(1.0))
decision_tree = DecisionTreeClassifier(max_depth=5)
random_forest = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
mlp = MLPClassifier(alpha=1, max_iter=1000)
ada = AdaBoostClassifier()
qda = QuadraticDiscriminantAnalysis()

# %%
#KNeighborsClassifier
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
score = knn.score(X_test, y_test)
print('Accuracy of Nearest Neighbors: ', score)
# Out:
# Accuracy of Nearest Neighbors:  0.9378079864061173

# %%
#DecisionTreeClassifier
decision_tree.fit(X_train, y_train)
y_pred = decision_tree.predict(X_test)
score = decision_tree.score(X_test, y_test)
print('Accuracy of Decision Tree: ', score)
# Out:
# Accuracy of Decision Tree:  0.5587085811384876

# %%
#RandomForestClassifier
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_test)
score = random_forest.score(X_test, y_test)
print('Accuracy of Random Forest: ', score)
# Out:
# Accuracy of Random Forest:  0.5971112999150382

# %%
#AdaBoostClassifier
ada.fit(X_train, y_train)
y_pred = ada.predict(X_test)
score = ada.score(X_test, y_test)
print('Accuracy of AdaBoost: ', score)
# Out:
# Accuracy of AdaBoost:  0.7063721325403568

# %%
#QuadraticDiscriminantAnalysis
qda.fit(X_train, y_train)
y_pred = qda.predict(X_test)
score = qda.score(X_test, y_test)
print('Accuracy of QDA: ', score)
# Out:
# Accuracy of QDA:  0.897536108751062
